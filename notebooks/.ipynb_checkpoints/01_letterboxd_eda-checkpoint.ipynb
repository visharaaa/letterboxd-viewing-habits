# %% [markdown]
# ## Getting Started

# %%
print ("Notebook is working!")
# Out:
# Notebook is working!

# %%
pip install pandas matplotlib seaborn
# Out:
# Collecting pandas
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/86/41/585a168330ff063014880a80d744219dbf1dd7a1c706e75ab3425a987384/pandas-2.3.3-cp312-cp312-win_amd64.whl.metadata
#   Using cached pandas-2.3.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting matplotlib
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/30/4e/c10f171b6e2f44d9e3a2b96efa38b1677439d79c99357600a62cc1e9594e/matplotlib-3.10.8-cp312-cp312-win_amd64.whl.metadata
#   Using cached matplotlib-3.10.8-cp312-cp312-win_amd64.whl.metadata (52 kB)
# Collecting seaborn
#   Obtaining dependency information for seaborn from https://files.pythonhosted.org/packages/83/11/00d3c3dfc25ad54e731d91449895a79e4bf2384dc3ac01809010ba88f6d5/seaborn-0.13.2-py3-none-any.whl.metadata
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\acer\pycharmprojects\letterboxd-viewing-habits\.venv\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\acer\pycharmprojects\letterboxd-viewing-habits\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\acer\pycharmprojects\letterboxd-viewing-habits\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\acer\pycharmprojects\letterboxd-viewing-habits\.venv\lib\site-packages (from pandas) (2025.3)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/19/e8/6026ed58a64563186a9ee3f29f41261fd1828f527dd93d33b60feca63352/contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata
#   Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/80/3b/a3e81b71aed5a688e89dfe0e2694b26b78c7d7f39a5ffd8a7d75f54a12a8/fonttools-4.61.1-cp312-cp312-win_amd64.whl.metadata
#   Using cached fonttools-4.61.1-cp312-cp312-win_amd64.whl.metadata (116 kB)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\acer\pycharmprojects\letterboxd-viewing-habits\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\acer\pycharmprojects\letterboxd-viewing-habits\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\acer\pycharmprojects\letterboxd-viewing-habits\.venv\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\acer\pycharmprojects\letterboxd-viewing-habits\.venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\acer\pycharmprojects\letterboxd-viewing-habits\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-2.3.3-cp312-cp312-win_amd64.whl (11.0 MB)
# Using cached matplotlib-3.10.8-cp312-cp312-win_amd64.whl (8.1 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.61.1-cp312-cp312-win_amd64.whl (2.3 MB)
# Installing collected packages: fonttools, cycler, contourpy, pandas, matplotlib, seaborn
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 matplotlib-3.10.8 pandas-2.3.3 seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print ("Packages loaded successfully")
# Out:
# Packages loaded successfully

# %% [markdown]
# ## Loading CSVs

# %%
ratings = pd.read_csv("../data/raw/ratings.csv")
diary = pd.read_csv("../data/raw/diary.csv")

ratings.head()
# Out:
#          Date                               Name  Year        Letterboxd URI  \
# 0  2024-05-16                           Parasite  2019  https://boxd.it/hTha
# 1  2024-05-16  Everything Everywhere All at Once  2022  https://boxd.it/jUk4
# 2  2024-05-16  Spider-Man: Into the Spider-Verse  2018  https://boxd.it/azpY
# 3  2024-05-16                          Midsommar  2019  https://boxd.it/jhxe
# 4  2024-05-16                           Saltburn  2023  https://boxd.it/z4eg
#
#    Rating
# 0     4.5
# 1     5.0
# 2     5.0
# 3     3.5
# 4     2.5

# %%
diary.head()
# Out:
#          Date                         Name  Year          Letterboxd URI  \
# 0  2024-05-16                         Soul  2020  https://boxd.it/6u3SED
# 1  2024-05-16  Taylor Swift: The Eras Tour  2023  https://boxd.it/6u3VJV
# 2  2024-05-16                       Barbie  2023  https://boxd.it/6u3VRZ
# 3  2024-05-16                    Elemental  2023  https://boxd.it/6u3SNv
# 4  2024-05-16                     Saltburn  2023  https://boxd.it/6u3UTl
#
#    Rating Rewatch          Tags Watched Date
# 0     5.0     NaN  with cousins   2024-01-12
# 1     4.5     NaN  with cousins   2024-01-13
# 2     5.0     Yes  with cousins   2024-01-14
# 3     5.0     NaN  with cousins   2024-01-15
# 4     2.5     NaN           NaN   2024-02-19

# %% [markdown]
# ## Data Cleaning

# %%
# Converting date columns to datetime

ratings['Date'] = pd.to_datetime(ratings['Date'], errors = 'coerce')
diary['Date'] = pd.to_datetime(diary['Date'], errors = 'coerce')
diary['Watched Date'] = pd.to_datetime(diary['Watched Date'], errors = 'coerce')

# Check conversion
ratings.head()
# Out:
#         Date                               Name  Year        Letterboxd URI  \
# 0 2024-05-16                           Parasite  2019  https://boxd.it/hTha
# 1 2024-05-16  Everything Everywhere All at Once  2022  https://boxd.it/jUk4
# 2 2024-05-16  Spider-Man: Into the Spider-Verse  2018  https://boxd.it/azpY
# 3 2024-05-16                          Midsommar  2019  https://boxd.it/jhxe
# 4 2024-05-16                           Saltburn  2023  https://boxd.it/z4eg
#
#    Rating
# 0     4.5
# 1     5.0
# 2     5.0
# 3     3.5
# 4     2.5

# %%
diary.head()
# Out:
#         Date                         Name  Year          Letterboxd URI  \
# 0 2024-05-16                         Soul  2020  https://boxd.it/6u3SED
# 1 2024-05-16  Taylor Swift: The Eras Tour  2023  https://boxd.it/6u3VJV
# 2 2024-05-16                       Barbie  2023  https://boxd.it/6u3VRZ
# 3 2024-05-16                    Elemental  2023  https://boxd.it/6u3SNv
# 4 2024-05-16                     Saltburn  2023  https://boxd.it/6u3UTl
#
#    Rating Rewatch          Tags Watched Date
# 0     5.0     NaN  with cousins   2024-01-12
# 1     4.5     NaN  with cousins   2024-01-13
# 2     5.0     Yes  with cousins   2024-01-14
# 3     5.0     NaN  with cousins   2024-01-15
# 4     2.5     NaN           NaN   2024-02-19

# %% [markdown]
# ## Visualization
#
# ### 1) Letterboxd Rating Curve

# %%
# Make column names lowercase and remove spaces
ratings.columns = ratings.columns.str.strip().str.lower()
diary.columns = diary.columns.str.strip().str.lower()

# Check columns again
print(ratings.columns)
# Out:
# Index(['date', 'name', 'year', 'letterboxd uri', 'rating'], dtype='object')

# %%
ratings.head()
# Out:
#         date                               name  year        letterboxd uri  \
# 0 2024-05-16                           Parasite  2019  https://boxd.it/hTha
# 1 2024-05-16  Everything Everywhere All at Once  2022  https://boxd.it/jUk4
# 2 2024-05-16  Spider-Man: Into the Spider-Verse  2018  https://boxd.it/azpY
# 3 2024-05-16                          Midsommar  2019  https://boxd.it/jhxe
# 4 2024-05-16                           Saltburn  2023  https://boxd.it/z4eg
#
#    rating
# 0     4.5
# 1     5.0
# 2     5.0
# 3     3.5
# 4     2.5

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))
sns.countplot(x='rating', data=ratings, palette='viridis')
plt.title("Distribution of Ratings")
plt.xlabel("Rating")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_26736\2394584938.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='rating', data=ratings, palette='viridis')

# %% [markdown]
# ### 2) Movies Watched According to Year

# %%
ratings['year'].head()
# Out:
# 0    2019
# 1    2022
# 2    2018
# 3    2019
# 4    2023
# Name: year, dtype: int64

# %%
ratings['year'] = pd.to_numeric(ratings['year'], errors='coerce')

# %%
movies_per_year = ratings['year'].value_counts().sort_index()
movies_per_year.head()
# Out:
# year
# 1960    1
# 1965    1
# 1986    1
# 1988    2
# 1989    4
# Name: count, dtype: int64

# %%
#using bar plot

plt.figure(figsize=(12,5))
sns.barplot(x=movies_per_year.index, y=movies_per_year.values, palette='coolwarm')
plt.xticks(rotation=45)  # rotate x-axis labels if needed
plt.title("Movies Watched per Year")
plt.xlabel("Year of Movie Release")
plt.ylabel("Number of Movies")
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_26736\3725207978.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=movies_per_year.index, y=movies_per_year.values, palette='coolwarm')

# %%
# Using a line plot

plt.figure(figsize=(12,5))
plt.plot(movies_per_year.index, movies_per_year.values, marker='o', color='teal')
plt.xticks(rotation=45)
plt.title("Movies Watched per Year")
plt.xlabel("Year of Movie Release")
plt.ylabel("Number of Movies")
plt.grid(True)
plt.show()
